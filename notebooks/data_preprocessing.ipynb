# %% [markdown]
# # Data Preprocessing
#
# This notebook demonstrates data cleaning and preprocessing for the hybrid recommendation system.

# %%
import sys
import os
sys.path.append('..')

from src.data_processing import load_data, preprocess_data, save_processed_data
import pandas as pd

# %%
# Load the raw dataset
df = load_data('../data/dataset.csv')
print(f"Dataset shape: {df.shape}")
df.head()

# %%
# Preprocess the data
df_processed = preprocess_data(df)
print(f"Processed dataset shape: {df_processed.shape}")
df_processed.head()

# %%
# Save processed data
save_processed_data(df_processed, '../data/processed_data.csv')
print("Processed data saved successfully!")
